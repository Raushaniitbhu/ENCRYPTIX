# %%
import numpy as np
import pandas as pd
from sklearn.model_selection import  train_test_split
from sklearn.linear_model import LogisticRegression
from sklearn.tree import DecisionTreeClassifier
from sklearn.ensemble import RandomForestClassifier


from sklearn.metrics import accuracy_score
from sklearn.metrics import f1_score
from sklearn.metrics import  recall_score

# %%
credit_card_data = pd.read_csv("/content/creditcard.csv")

# %%
credit_card_data.head()
# Out:
#    Time        V1        V2        V3        V4        V5        V6        V7  \
# 0     0 -1.359807 -0.072781  2.536347  1.378155 -0.338321  0.462388  0.239599
# 1     0  1.191857  0.266151  0.166480  0.448154  0.060018 -0.082361 -0.078803
# 2     1 -1.358354 -1.340163  1.773209  0.379780 -0.503198  1.800499  0.791461
# 3     1 -0.966272 -0.185226  1.792993 -0.863291 -0.010309  1.247203  0.237609
# 4     2 -1.158233  0.877737  1.548718  0.403034 -0.407193  0.095921  0.592941
#
#          V8        V9  ...       V21       V22       V23       V24       V25  \
# 0  0.098698  0.363787  ... -0.018307  0.277838 -0.110474  0.066928  0.128539
# 1  0.085102 -0.255425  ... -0.225775 -0.638672  0.101288 -0.339846  0.167170
# 2  0.247676 -1.514654  ...  0.247998  0.771679  0.909412 -0.689281 -0.327642
# 3  0.377436 -1.387024  ... -0.108300  0.005274 -0.190321 -1.175575  0.647376
# 4 -0.270533  0.817739  ... -0.009431  0.798278 -0.137458  0.141267 -0.206010
#
# ...

# %%
credit_card_data.shape
# Out:
# (11959, 31)

# %%
credit_card_data.tail()
# Out:
#         Time        V1        V2        V3        V4        V5        V6  \
# 11954  20631  1.504204 -0.411728  0.200090 -0.778753 -0.442232 -0.119677
# 11955  20636  1.134994  0.096340  0.277921  0.319692  0.742800  1.611803
# 11956  20638 -6.305012  3.944886 -4.707362  1.539602 -3.934785 -1.730565
# 11957  20638  1.161960 -0.398297  1.123732 -0.474237 -1.226667 -0.519325
# 11958  20642  1.291096 -0.226628  0.708386 -0.719236 -0.659099 -0.273757
#
#              V7        V8        V9  ...       V21       V22       V23  \
# 11954 -0.782660 -0.165178  0.691819  ... -0.136231 -0.217274 -0.143260
# 11955 -0.458649  0.390012  1.424541  ... -0.395605 -0.743542  0.222256
# 11956 -2.104936  3.843447  0.863458  ...  0.073140 -0.039935 -0.108896
# 11957 -0.804179  0.070134  3.262926  ... -0.121191  0.097255  0.050903
# 11958 -0.612042 -0.111488  3.032258  ...       NaN       NaN       NaN
#
#             V24       V25       V26       V27       V28  Amount  Class
# ...

# %%
credit_card_data.describe()
# Out:
#                Time            V1            V2            V3            V4  \
# count  11959.000000  11959.000000  11959.000000  11959.000000  11959.000000
# mean    8009.996822     -0.216230      0.277097      0.889505      0.282606
# std     6204.332248      1.583914      1.308884      1.331824      1.478162
# min        0.000000    -27.670569    -34.607649    -22.804686     -4.657545
# 25%     2542.000000     -0.978944     -0.261503      0.417186     -0.622456
# 50%     6662.000000     -0.340742      0.256346      0.951223      0.213029
# 75%    12382.000000      1.161273      0.883626      1.613678      1.159141
# max    20642.000000      1.960497      9.092123      4.101716     11.927512
#
#                  V5            V6            V7            V8            V9  \
# count  11959.000000  11959.000000  11959.000000  11959.000000  11959.000000
# mean      -0.086585      0.139986     -0.121943     -0.048727      0.911579
# ...

# %%
credit_card_data.isnull().sum()
# Out:
# Time      0
# V1        0
# V2        0
# V3        0
# V4        0
# V5        0
# V6        0
# V7        0
# V8        0
# V9        0
# V10       0
# V11       0
# V12       0
# V13       0
# V14       0
# V15       0
# V16       0
# V17       0
# V18       0
# V19       0
# V20       1
# V21       1
# V22       1
# V23       1
# V24       1
# V25       1
# V26       1
# V27       1
# V28       1
# Amount    1
# Class     1
# dtype: int64

# %% [markdown]
# V20,V21,V22,V23,V24,V25, V26, V27, V28 ,Amount ,Class  these columns contains null values . so now i removed the null values

# %%
#dropping the last rows because its contains null values
df = credit_card_data.dropna()

# %%
df.isnull().sum()
# now there is no null values in the datasets
# Out:
# Time      0
# V1        0
# V2        0
# V3        0
# V4        0
# V5        0
# V6        0
# V7        0
# V8        0
# V9        0
# V10       0
# V11       0
# V12       0
# V13       0
# V14       0
# V15       0
# V16       0
# V17       0
# V18       0
# V19       0
# V20       0
# V21       0
# V22       0
# V23       0
# V24       0
# V25       0
# V26       0
# V27       0
# V28       0
# Amount    0
# Class     0
# dtype: int64

# %%
df.describe()
# Out:
#                Time            V1            V2            V3            V4  \
# count  11958.000000  11958.000000  11958.000000  11958.000000  11958.000000
# mean    8008.940458     -0.216356      0.277139      0.889520      0.282689
# std     6203.516081      1.583920      1.308931      1.331879      1.478195
# min        0.000000    -27.670569    -34.607649    -22.804686     -4.657545
# 25%     2542.000000     -0.978957     -0.261503      0.417182     -0.621757
# 50%     6661.500000     -0.340925      0.256551      0.951225      0.213050
# 75%    12378.000000      1.161229      0.883785      1.613701      1.159181
# max    20638.000000      1.960497      9.092123      4.101716     11.927512
#
#                  V5            V6            V7            V8            V9  \
# count  11958.000000  11958.000000  11958.000000  11958.000000  11958.000000
# mean      -0.086537      0.140021     -0.121902     -0.048722      0.911402
# ...

# %%
df.tail()
# Out:
#         Time        V1        V2        V3        V4        V5        V6  \
# 11953  20625 -0.653155  0.372141  2.209254 -2.151937  0.451189  0.822337
# 11954  20631  1.504204 -0.411728  0.200090 -0.778753 -0.442232 -0.119677
# 11955  20636  1.134994  0.096340  0.277921  0.319692  0.742800  1.611803
# 11956  20638 -6.305012  3.944886 -4.707362  1.539602 -3.934785 -1.730565
# 11957  20638  1.161960 -0.398297  1.123732 -0.474237 -1.226667 -0.519325
#
#              V7        V8        V9  ...       V21       V22       V23  \
# 11953  0.267881  0.083443  2.295254  ... -0.149850  0.151803 -0.505597
# 11954 -0.782660 -0.165178  0.691819  ... -0.136231 -0.217274 -0.143260
# 11955 -0.458649  0.390012  1.424541  ... -0.395605 -0.743542  0.222256
# 11956 -2.104936  3.843447  0.863458  ...  0.073140 -0.039935 -0.108896
# 11957 -0.804179  0.070134  3.262926  ... -0.121191  0.097255  0.050903
#
#             V24       V25       V26       V27       V28  Amount  Class
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 11958 entries, 0 to 11957
# Data columns (total 31 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   Time    11958 non-null  int64
#  1   V1      11958 non-null  float64
#  2   V2      11958 non-null  float64
#  3   V3      11958 non-null  float64
#  4   V4      11958 non-null  float64
#  5   V5      11958 non-null  float64
#  6   V6      11958 non-null  float64
#  7   V7      11958 non-null  float64
#  8   V8      11958 non-null  float64
#  9   V9      11958 non-null  float64
#  10  V10     11958 non-null  float64
#  11  V11     11958 non-null  float64
#  12  V12     11958 non-null  float64
#  13  V13     11958 non-null  float64
#  14  V14     11958 non-null  float64
#  15  V15     11958 non-null  float64
#  16  V16     11958 non-null  float64
#  17  V17     11958 non-null  float64
#  18  V18     11958 non-null  float64
#  19  V19     11958 non-null  float64
# ...

# %%
df["Class"].value_counts()
# Out:
# Class
# 0.0    11906
# 1.0       52
# Name: count, dtype: int64

# %% [markdown]
# this datasets is very unbalanced because number of fraud transaction is very very less than the legitimate transaction
# 0.0 - normal transaction
# 1.0  -  fraud transaction

# %%
legit = df[df.Class==0]
fraud = df[df.Class==1]

# %%
print(legit.shape)
print(fraud.shape)
# Out:
# (11906, 31)
# (52, 31)

# %%
legit.Amount.describe()
# Out:
# count    11906.000000
# mean        62.198127
# std        177.379105
# min          0.000000
# 25%          5.292500
# 50%         15.950000
# 75%         50.000000
# max       7712.430000
# Name: Amount, dtype: float64

# %%
fraud.Amount.describe()
# Out:
# count      52.000000
# mean       97.724808
# std       321.188775
# min         0.000000
# 25%         1.000000
# 50%         1.000000
# 75%         1.772500
# max      1809.680000
# Name: Amount, dtype: float64

# %%
df.groupby("Class").mean()
# Out:
#                Time        V1        V2        V3        V4        V5  \
# Class
# 0.0     7993.389048 -0.200839  0.259753  0.929229  0.255987 -0.076685
# 1.0    11569.615385 -3.769104  4.258027 -8.202329  6.396396 -2.342431
#
#              V6        V7        V8        V9  ...       V20       V21  \
# Class                                          ...
# 0.0    0.149326 -0.097364 -0.053087  0.927305  ...  0.020836 -0.063076
# 1.0   -1.990562 -5.740207  0.950650 -2.729769  ...  0.411236  0.305259
#
#             V22       V23       V24       V25       V26       V27       V28  \
# Class
# 0.0   -0.154427 -0.032369  0.018962  0.105861  0.061825  0.005330  0.000012
# 1.0   -0.021762 -0.340563 -0.406311 -0.139505  0.306967  0.692927  0.059751
#
#           Amount
# Class
# 0.0    62.198127
# 1.0    97.724808
#
# [2 rows x 30 columns]

# %% [markdown]
# build a sample dataset containing similar no of normal transaction and fraud transaction
#
# number of fraud transaction is 52

# %%
legit_sample = legit.sample(n=52)
legit_sample.shape
# Out:
# (52, 31)

# %% [markdown]
# concatenating the two dataframs

# %%
legit_sample = pd.concat([legit_sample , fraud] , axis =0)

# %%
new_df.shape
# Out:
# (104, 31)

# %%
new_df["Class"].value_counts()
# Out:
# Class
# 0.0    52
# 1.0    52
# Name: count, dtype: int64

# %%
new_df.groupby("Class").mean()
# Out:
#                Time        V1        V2        V3        V4        V5  \
# Class
# 0.0     8481.576923  0.007993  0.340321  0.861878  0.102048 -0.066968
# 1.0    11569.615385 -3.769104  4.258027 -8.202329  6.396396 -2.342431
#
#              V6        V7        V8        V9  ...       V20       V21  \
# Class                                          ...
# 0.0    0.159265 -0.308401 -0.069445  0.982129  ...  0.042909 -0.108615
# 1.0   -1.990562 -5.740207  0.950650 -2.729769  ...  0.411236  0.305259
#
#             V22       V23       V24       V25       V26       V27       V28  \
# Class
# 0.0   -0.191166 -0.082834  0.073383  0.098776  0.002387 -0.007100 -0.022588
# 1.0   -0.021762 -0.340563 -0.406311 -0.139505  0.306967  0.692927  0.059751
#
#           Amount
# Class
# 0.0    34.862115
# 1.0    97.724808
#
# [2 rows x 30 columns]

# %% [markdown]
# Splitting the data into features and target

# %%
X = new_df.drop(columns = 'Class' , axis =1)
Y = new_df['Class']

# %%
print(X)
# Out:
#         Time         V1        V2         V3         V4        V5        V6  \
# 3524    3012  -0.302521  0.447474  -0.495757  -3.214799  2.705041  2.762440
# 10090  15324  -3.690755  3.414470   0.714492  -1.985861 -0.543478 -1.366884
# 2175    1691   1.167127 -0.786879  -0.512053  -0.886366  1.275574  3.890854
# 8333   11125   1.430316 -0.157331  -0.149474  -0.656369 -0.243137 -0.813693
# 5792    6213  -1.844504  3.740045  -3.866049   1.685659 -0.391838 -1.359432
# ...      ...        ...       ...        ...        ...       ...       ...
# 10897  18690 -15.398845  7.472324 -19.026912  11.165526 -6.893856 -2.120937
# 11343  19762 -14.179165  7.421370 -21.405836  11.927512 -7.974281 -2.202710
# 11710  20011 -14.724627  7.875157 -21.872317  11.906170 -8.348734 -2.262846
# 11841  20332 -15.271362  8.326581 -22.338591  11.885313 -8.721334 -2.324307
# 11880  20451 -15.819179  8.775997 -22.804686  11.864868 -9.092361 -2.386893
#
# ...

# %%
print(Y)
# Out:
# 3524     0.0
# 10090    0.0
# 2175     0.0
# 8333     0.0
# 5792     0.0
#         ...
# 10897    1.0
# 11343    1.0
# 11710    1.0
# 11841    1.0
# 11880    1.0
# Name: Class, Length: 104, dtype: float64

# %% [markdown]
# SPLITTING the data into training data and test data

# %%
X_train , X_test ,Y_train , Y_test = train_test_split(X,Y,test_size = 0.2 , stratify =Y ,random_state =2)

# %%
print(X.shape ,X_train.shape , X_test.shape)
# Out:
# (104, 30) (83, 30) (21, 30)

# %% [markdown]
# MODEL training
#
# Using logistic regression

# %%
lr = LogisticRegression()

# %% [markdown]
# **training the logistic regression model with training data**
#
# ---

# %%
lr.fit(X_train,Y_train )
# Out:
# /usr/local/lib/python3.10/dist-packages/sklearn/linear_model/_logistic.py:458: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# LogisticRegression()

# %%
# Predict on the test data
X_test_pred = lr.predict(X_test)

# Calculate accuracy of the model
accuracy = accuracy_score(X_test_pred , Y_test)
print(accuracy)

# Calculate recall of the model
recall= recall_score(X_test_pred,Y_test)
print(recall)
# Out:
# 0.9047619047619048
# 0.9

# %% [markdown]
# **Applying Decision tree classifier**

# %%
clf = DecisionTreeClassifier()

# Train the classifier
clf.fit(X_train, Y_train)

# Predict on the test data
X_test_pred = clf.predict(X_test)

# Calculate accuracy of the classifier
accuracy = accuracy_score(X_test_pred , Y_test)
print(accuracy)

# Calculate recall of the classifier
recall= recall_score(X_test_pred,Y_test)
print(recall)
# Out:
# 0.9523809523809523
# 1.0

# %% [markdown]
# # Using Random Forest classifier

# %%
# Initialize Random Forest classifier
clf = RandomForestClassifier(n_estimators=100 )

# Train the classifier
clf.fit(X_train, Y_train)

# Predict on the test data
X_test_pred = clf.predict(X_test)

# Calculate accuracy of the classifier
accuracy = accuracy_score(X_test_pred , Y_test)
print(accuracy)

# Calculate recall of the classifier
recall= recall_score(X_test_pred,Y_test)
print(recall)
# Out:
# 0.9523809523809523
# 1.0
